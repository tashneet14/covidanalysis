# %% [markdown]
# # ***Detailed Analysis of COVID-19 from 22/01/2020 to 27/07/2020***

# %% [markdown]
# ### using Data Analysis and Data Visualisation in Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  #importing necessary libraries

# %%
data=pd.read_csv(r"C:\Users\lenovo\Downloads\archive (1)\day_wise.csv")#importing data set

# %%
data  #displaying data
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
a= pd.read_csv(r"C:\Users\lenovo\Downloads\archive (1)\day_wise.csv",parse_dates=['Date'],index_col= ['Date'],na_values=['999.99'])

# %%
data.columns #dispalying columns in data
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
data.describe() #describing the data
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
data.info()  #info from data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
data.corr()  #correlation
# Out:
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.975981   0.990165  0.986543   0.961473
# Deaths                   0.975981  1.000000   0.936940  0.996879   0.952450
# Recovered                0.990165  0.936940   1.000000  0.953981   0.936576
# Active                   0.986543  0.996879   0.953981  1.000000   0.967578
# New cases                0.961473  0.952450   0.936576  0.967578   1.000000
# New deaths               0.555479  0.625537   0.476217  0.637241   0.721846
# New recovered            0.944875  0.923130   0.935754  0.931824   0.928570
# Deaths / 100 Cases       0.221469  0.383897   0.096131  0.364250   0.367629
# Recovered / 100 Cases    0.720283  0.715555   0.711328  0.711695   0.670914
# Deaths / 100 Recovered  -0.400336 -0.410470  -0.382937 -0.410725  -0.405802
# No. of countries         0.595890  0.683543   0.510129  0.683194   0.722150
#
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 6))

# Add x-axis and y-axis
ax.bar(a.index.values,
       a['Confirmed'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Confirmed cases",
       title="The surge of Covid-19")

plt.show()

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(data.corr()) #implementation of heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***The above heatmap shows the positive and negative correlations of various columns wrt each other using mentioned color density***

# %% [markdown]
# ## Relation plots

# %%
sns.relplot(x='Confirmed',y='Active',data=data,kind='line')

# %% [markdown]
# ***The above graph suggests that the active cases increased with the increase in confirmed cases but gradually flattens due to impose of lockdown and strict measures applied in all the countries***

# %%
sns.relplot(x='Confirmed',y='Deaths',data=data,kind='scatter',hue='New deaths')

# %% [markdown]
# ***According to the plot initially deaths increased at a higher rate wrt confirmed cases but after global 2,00,000 deaths starts reducing due to improved healthcare and knowledge related to covid with time***

# %%
sns.relplot(x='Confirmed',y='Recovered',data=data,kind='scatter',hue='New recovered')

# %% [markdown]
# ***Recovered cases have increased at a good pace in the mentioned time period depicting that covid has lost its grip with passing of time***

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(x='Confirmed',y='No. of countries',data=data)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='No. of countries'>

# %% [markdown]
# ***The spread of corona virus was limited to nearly 25 countries for brief period of time but due to effect of continuous increase in confirmed cases and some countries reluctant to seal the borders and imposing strict lockdown rules more and more countries start getting affected and soon it was declared pandemic by WHO and within some days the deadly virus wrecked havoc on 90% of the globe.***

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data)

# %% [markdown]
# ***This is the pair plot depicting plotting of each column wrt all other columns***

# %% [markdown]
# ## Distplot

# %%
sns.distplot(data['Recovered / 100 Cases'],color='red')
# Out:
# <AxesSubplot:xlabel='Recovered / 100 Cases', ylabel='Density'>

# %% [markdown]
# ***The density is highest for the range 50-60 which means for most of the days 50-60 patients were recovered per 100 cases***

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(x='New cases',y='New deaths',data=data,kind='hex')

# %% [markdown]
# ***The plot suggests that after the initial surge, most new deaths(4000-8000) were reported when the new cases were ranging from 60,000 to 1,40,000 approximately***

# %% [markdown]
# ## MATPLOTLIB PLOT

# %%
fig, ax = plt.subplots(figsize=(6, 6))

# Add x-axis and y-axis
ax.plot(a.index.values,
       a['New recovered'],
       color='green')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="New recovered cases",
       title="Beating coronavirus")

plt.show()

# %% [markdown]
# ***The increase in new recovered cases suggest that the virus gradually lost control during the specified time period***

# %% [markdown]
# ## Increase in recovery % from 22/01/2020 to 27/07/2020

# %%
labels=['Active','Recovered','Deaths']
sizes=[510,28,17]
colors=['blue','gold','yellowgreen']
explode=[0,0.1,0]
plt.pie(sizes,labels=labels,explode=explode,colors=colors,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ddcee50400>,
# ...
#  [Text(-1.0645062318075214, 0.27717590523519847, 'Active'),
#   Text(1.1268547047305, -0.4125511779485518, 'Recovered'),
#   Text(1.0949109150168732, -0.10568863787992377, 'Deaths')],
#  [Text(-0.5806397628041026, 0.1511868574010173, '91.9%'),
#   Text(0.6573319110927917, -0.24065485380332186, '5.0%'),
#   Text(0.597224135463749, -0.05764834793450387, '3.1%')])

# %%
labels=['Active','Recovered','Deaths']
sizes=[6358362,9468087,654036]
colors=['blue','gold','yellowgreen']
explode=[0,0.1,0]
plt.pie(sizes,labels=labels,explode=explode,colors=colors,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ddcedff0a0>,
# ...
#  [Text(0.3861974475893497, 1.0299764713212975, 'Active'),
#   Text(-0.5577602927815186, -1.0624986850797862, 'Recovered'),
#   Text(1.0914618844402324, -0.13678799221487548, 'Deaths')],
#  [Text(0.21065315323055436, 0.561805347993435, '38.6%'),
#   Text(-0.32536017078921914, -0.6197908996298753, '57.5%'),
#   Text(0.5953428460583086, -0.0746116321172048, '4.0%')])

# %% [markdown]
# ## Conclusion:-

# %% [markdown]
# From the report it can be concluded that the cases continuosly increased at a rapid pace and the virus extended its reach to almost all countries in the world. After the lockdown was imposed the recovery % starts increasing at a healthy rate also reducing the number of deaths. This data set was helpful in understanding the scenario of Covid-19 in the world in given time period
